# %% [markdown]
# **1.** Import pandas under the alias `pd`.

# %%
import pandas as pd

# %% [markdown]
# **2.** Print the version of pandas that has been imported.

# %%
pd.__version__
# Out:
# '2.2.3'

# %% [markdown]
# **3.** Create a DataFrame `df` from this dictionary `data` which has the index `labels`.
#
# ``` python
# data = {'animal': ['cat', 'cat', 'snake', 'dog', 'dog', 'cat', 'snake', 'cat', 'dog', 'dog'],
#         'age': [2.5, 3, 0.5, np.nan, 5, 2, 4.5, np.nan, 7, 3],
#         'visits': [1, 3, 2, 3, 2, 3, 1, 1, 2, 1],
#         'priority': ['yes', 'yes', 'no', 'yes', 'no', 'no', 'no', 'yes', 'no', 'no']}
#
# labels = ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j']
# ```

# %%
import numpy as np
data = {'animal': ['cat', 'cat', 'snake', 'dog', 'dog', 'cat', 'snake', 'cat', 'dog', 'dog'],
        'age': [2.5, 3, 0.5, np.nan, 5, 2, 4.5, np.nan, 7, 3],
        'visits': [1, 3, 2, 3, 2, 3, 1, 1, 2, 1],
        'priority': ['yes', 'yes', 'no', 'yes', 'no', 'no', 'no', 'yes', 'no', 'no']}

labels = ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j']

df = pd.DataFrame(data, index=labels)
df
# Out:
#   animal  age  visits priority
# a    cat  2.5       1      yes
# b    cat  3.0       3      yes
# c  snake  0.5       2       no
# d    dog  NaN       3      yes
# e    dog  5.0       2       no
# f    cat  2.0       3       no
# g  snake  4.5       1       no
# h    cat  NaN       1      yes
# i    dog  7.0       2       no
# j    dog  3.0       1       no

# %% [markdown]
# **4.** Display a summary of the basic information about this DataFrame and its data (*hint: there is a single method that can be called on the DataFrame*).

# %%
df.info()
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10 entries, a to j
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   animal    10 non-null     object
#  1   age       8 non-null      float64
#  2   visits    10 non-null     int64
#  3   priority  10 non-null     object
# dtypes: float64(1), int64(1), object(2)
# memory usage: 400.0+ bytes
#             age     visits
# count  8.000000  10.000000
# mean   3.437500   1.900000
# std    2.007797   0.875595
# min    0.500000   1.000000
# 25%    2.375000   1.000000
# 50%    3.000000   2.000000
# 75%    4.625000   2.750000
# max    7.000000   3.000000

# %% [markdown]
# **5.** Return the first 3 rows of the DataFrame `df`.

# %%
df.head(3)
df.loc[:'c']
df.iloc[:3]
# Out:
#   animal  age  visits priority
# a    cat  2.5       1      yes
# b    cat  3.0       3      yes
# c  snake  0.5       2       no

# %% [markdown]
# **6.** Select just the 'animal' and 'age' columns from the DataFrame `df`.

# %%
df[['animal', 'age']]
df.loc[:, ['animal', 'age']]
df.iloc[:,0:2]
# Out:
#   animal  age
# a    cat  2.5
# b    cat  3.0
# c  snake  0.5
# d    dog  NaN
# e    dog  5.0
# f    cat  2.0
# g  snake  4.5
# h    cat  NaN
# i    dog  7.0
# j    dog  3.0

# %% [markdown]
# **7.** Select the data in rows `[3, 4, 8]` *and* in columns `['animal', 'age']`.

# %%
df.loc[['d', 'e', 'i'], ['animal', 'age']]
df.loc[df.index[[3, 4, 8]], ['animal', 'age']]
df.loc[df.index[[3, 4, 8]], 'animal': 'age']
# Out:
#   animal  age
# d    dog  NaN
# e    dog  5.0
# i    dog  7.0

# %%
df.iloc[[3, 4, 8], 0:2]
df.iloc[[3, 4, 8], [0,1]]
df.iloc[[3, 4, 8], [0,1]]
# Out:
#   animal  age
# d    dog  NaN
# e    dog  5.0
# i    dog  7.0

# %% [markdown]
# **8.** Select only the rows where the number of visits is greater than 1.

# %%
import numpy as np
df.loc[df.index[df['visits']>1]]
df.loc[df['visits']>1]
df[df['visits']>1]
df.iloc[np.where(df['visits'] > 1)]
# Out:
#   animal  age  visits priority
# b    cat  3.0       3      yes
# c  snake  0.5       2       no
# d    dog  NaN       3      yes
# e    dog  5.0       2       no
# f    cat  2.0       3       no
# i    dog  7.0       2       no

# %% [markdown]
# **9.** Select the rows where the age is missing, i.e. it is `NaN`.

# %%
df.iloc[np.where(df['age'].isnull())]
df.loc[df['age'].isnull()]
df[df['age'].isnull()]
df[df['age'].isna()]
# Out:
#   animal  age  visits priority
# d    dog  NaN       3      yes
# h    cat  NaN       1      yes

# %% [markdown]
# **10.** Select the rows where the animal is a cat *and* the age is less than 3.

# %%
df[(df['animal'] == 'cat') & (df['age'] < 3)]
# Out:
#   animal  age  visits priority
# a    cat  2.5       1      yes
# f    cat  2.0       3       no

# %% [markdown]
# **11.** Select the rows the age is between 2 and 4 (inclusive).

# %%
df[(df['age'] >= 2) & (df['age'] <= 4)]
df[df['age'].between(2,4,inclusive='both')]
# Out:
#   animal  age  visits priority
# a    cat  2.5       1      yes
# b    cat  3.0       3      yes
# f    cat  2.0       3       no
# j    dog  3.0       1       no

# %% [markdown]
# **12.** Change the age in row 'f' to 1.5.

# %%
df.loc['f', 'age'] = 1.5
df.at['f', 'age']  = 1.5

# %% [markdown]
# **13.** Calculate the sum of all visits in `df` (i.e. find the total number of visits).

# %%
df['visits'].sum()
# Out:
# np.int64(19)

# %% [markdown]
# **14.** Calculate the mean age for each different animal in `df`.

# %%
df.groupby('animal')['age'].mean()
# Out:
# animal
# cat      2.333333
# dog      5.000000
# snake    2.500000
# Name: age, dtype: float64

# %% [markdown]
# **15.** Append a new row 'k' to `df` with your choice of values for each column. Then delete that row to return the original DataFrame.

# %%
df.loc['k'] = ['octopus', 6.6, 2, 'yes']
df = df.drop('k')
df
# Out:
#   animal  age  visits priority
# a    cat  2.5       1      yes
# b    cat  3.0       3      yes
# c  snake  0.5       2       no
# d    dog  NaN       3      yes
# e    dog  5.0       2       no
# f    cat  1.5       3       no
# g  snake  4.5       1       no
# h    cat  NaN       1      yes
# i    dog  7.0       2       no
# j    dog  3.0       1       no

# %% [markdown]
# **16.** Count the number of each type of animal in `df`.

# %%
df['animal'].value_counts()
# Out:
# animal
# cat      4
# dog      4
# snake    2
# Name: count, dtype: int64

# %% [markdown]
# **17.** Sort `df` first by the values in the 'age' in *decending* order, then by the value in the 'visits' column in *ascending* order (so row `i` should be first, and row `d` should be last).

# %%
df.sort_values(by=['age', 'visits'], ascending=[False, True])
# Out:
#   animal  age  visits priority
# i    dog  7.0       2       no
# e    dog  5.0       2       no
# g  snake  4.5       1       no
# j    dog  3.0       1       no
# b    cat  3.0       3      yes
# a    cat  2.5       1      yes
# f    cat  1.5       3       no
# c  snake  0.5       2       no
# h    cat  NaN       1      yes
# d    dog  NaN       3      yes

# %% [markdown]
# **18.** The 'priority' column contains the values 'yes' and 'no'. Replace this column with a column of boolean values: 'yes' should be `True` and 'no' should be `False`.

# %%
df['priority'] = df['priority'].map({'yes': True, 'no': False})
df['priority'] = df['priority'].apply(lambda x: True if x == 'yes' else False)
df
# Out:
#   animal  age  visits  priority
# a    cat  2.5       1     False
# b    cat  3.0       3     False
# c  snake  0.5       2     False
# d    dog  NaN       3     False
# e    dog  5.0       2     False
# f    cat  1.5       3     False
# g  snake  4.5       1     False
# h    cat  NaN       1     False
# i    dog  7.0       2     False
# j    dog  3.0       1     False

# %% [markdown]
# **19.** In the 'animal' column, change the 'snake' entries to 'python'.

# %%
df['animal'] = df['animal'].replace('snake', 'python')
df
# Out:
#    animal  age  visits  priority
# a     cat  2.5       1     False
# b     cat  3.0       3     False
# c  python  0.5       2     False
# d     dog  NaN       3     False
# e     dog  5.0       2     False
# f     cat  1.5       3     False
# g  python  4.5       1     False
# h     cat  NaN       1     False
# i     dog  7.0       2     False
# j     dog  3.0       1     False

# %% [markdown]
# **20.** For each animal type and each number of visits, find the mean age. In other words, each row is an animal, each column is a number of visits and the values are the mean ages (*hint: use a pivot table*).

# %%
df.pivot_table(index='animal', columns='visits', values='age', aggfunc='mean')
# Out:
# visits    1    2     3
# animal
# cat     2.5  NaN  2.25
# dog     3.0  6.0   NaN
# python  4.5  0.5   NaN

# %% [markdown]
# **21.** Given a DataFrame of numeric values, say
# ```python
# df = pd.DataFrame(np.random.random(size=(5, 3))) # a 5x3 frame of float values
# ```
#
# how do you subtract the row mean from each element in the row?

# %%
df = pd.DataFrame(np.random.random(size=(5, 3)))
df.sub(df.mean(axis=1), axis=0)

# Explanation
# df.mean(axis=1) # Computes the mean for each row (along the columns).
# .sub(..., axis=0) # Broadcasts subtraction row-wise.

## Same for columns
# df.sub(df.mean(axis=0), axis=1)
# df.mean(axis=0) # Computes the mean for each column (along the rows).
# .sub(..., axis=1) # Broadcasts subtraction column-wise.
# Out:
#           0         1         2
# 0 -0.025915  0.050256 -0.024341
# 1 -0.007352  0.000303  0.007049
# 2  0.492164 -0.276812 -0.215353
# 3 -0.385723  0.345365  0.040358
# 4 -0.335362 -0.035416  0.370778

# %% [markdown]
# **22.** How do you count how many unique rows a DataFrame has (i.e. ignore all rows that are duplicates)? As input, use a DataFrame of zeros and ones with 10 rows and 3 columns.
#
# ```python
# df = pd.DataFrame(np.random.randint(0, 2, size=(10, 3)))
# ```

# %%
df = pd.DataFrame(np.random.randint(0, 2, size=(10, 3)))
display(df)
len(df.drop_duplicates(keep=False))
# Out:
#    0  1  2
# 0  0  0  1
# 1  0  0  1
# 2  0  0  1
# 3  0  0  0
# 4  1  0  1
# 5  1  1  0
# 6  0  1  0
# 7  0  1  1
# 8  1  1  0
# 9  0  1  0
# 3

# %% [markdown]
# **23.** Some values in the the **FlightNumber** column are missing (they are `NaN`). These numbers are meant to increase by 10 with each row so 10055 and 10075 need to be put in place. Modify `df` to fill in these missing numbers and make the column an integer column (instead of a float column).

# %%
df = pd.DataFrame({'From_To': ['LoNDon_paris', 'MAdrid_miLAN', 'londON_StockhOlm', 
                               'Budapest_PaRis', 'Brussels_londOn'],
              'FlightNumber': [10045, np.nan, 10065, np.nan, 10085],
              'RecentDelays': [[23, 47], [], [24, 43, 87], [13], [67, 32]],
                   'Airline': ['KLM(!)', '<Air France> (12)', '(British Airways. )', 
                               '12. Air France', '"Swiss Air"']})
df
# Out:
#             From_To  FlightNumber  RecentDelays              Airline
# 0      LoNDon_paris       10045.0      [23, 47]               KLM(!)
# 1      MAdrid_miLAN           NaN            []    <Air France> (12)
# 2  londON_StockhOlm       10065.0  [24, 43, 87]  (British Airways. )
# 3    Budapest_PaRis           NaN          [13]       12. Air France
# 4   Brussels_londOn       10085.0      [67, 32]          "Swiss Air"

# %%
df['FlightNumber'] = df['FlightNumber'].interpolate().astype(int)
df
# Out:
#             From_To  FlightNumber  RecentDelays              Airline
# 0      LoNDon_paris         10045      [23, 47]               KLM(!)
# 1      MAdrid_miLAN         10055            []    <Air France> (12)
# 2  londON_StockhOlm         10065  [24, 43, 87]  (British Airways. )
# 3    Budapest_PaRis         10075          [13]       12. Air France
# 4   Brussels_londOn         10085      [67, 32]          "Swiss Air"

# %% [markdown]
# **24.** The **From\_To** column would be better as two separate columns! Split each string on the underscore delimiter `_` to give a new temporary DataFrame called 'temp' with the correct values. Assign the correct column names 'From' and 'To' to this temporary DataFrame.

# %%
temp = df.From_To.str.split('_', expand=True)
temp.columns = ['From', 'To']
temp
# Out:
#        From         To
# 0    LoNDon      paris
# 1    MAdrid      miLAN
# 2    londON  StockhOlm
# 3  Budapest      PaRis
# 4  Brussels     londOn

# %% [markdown]
# **25.** Notice how the capitalisation of the city names is all mixed up in this temporary DataFrame 'temp'. Standardise the strings so that only the first letter is uppercase (e.g. "londON" should become "London".)

# %%
temp['From'] = temp['From'].str.capitalize()
temp['To'] = temp['To'].str.capitalize()
temp
# Out:
#        From         To
# 0    London      Paris
# 1    Madrid      Milan
# 2    London  Stockholm
# 3  Budapest      Paris
# 4  Brussels     London

# %% [markdown]
# **26.** Delete the **From_To** column from `df` and attach the temporary DataFrame 'temp' from the previous questions.

# %%
df = df.drop('From_To', axis=1)
df = df.join(temp)
df
# Out:
#    FlightNumber  RecentDelays              Airline      From         To
# 0         10045      [23, 47]               KLM(!)    London      Paris
# 1         10055            []    <Air France> (12)    Madrid      Milan
# 2         10065  [24, 43, 87]  (British Airways. )    London  Stockholm
# 3         10075          [13]       12. Air France  Budapest      Paris
# 4         10085      [67, 32]          "Swiss Air"  Brussels     London

# %% [markdown]
# **27**. In the **Airline** column, you can see some extra puctuation and symbols have appeared around the airline names. Pull out just the airline name. E.g. `'(British Airways. )'` should become `'British Airways'`.

# %%
df['Airline'] = df['Airline'].str.extract('([a-zA-Z]+)', expand=False).str.strip()
df
# Out:
#    FlightNumber  RecentDelays  Airline      From         To
# 0         10045      [23, 47]      KLM    London      Paris
# 1         10055            []      Air    Madrid      Milan
# 2         10065  [24, 43, 87]  British    London  Stockholm
# 3         10075          [13]      Air  Budapest      Paris
# 4         10085      [67, 32]    Swiss  Brussels     London

# %% [markdown]
# **28**. In the RecentDelays column, the values have been entered into the DataFrame as a list. We would like each first value in its own column, each second value in its own column, and so on. If there isn't an Nth value, the value should be NaN.
#
# Expand the Series of lists into a DataFrame named `delays`, rename the columns `delay_1`, `delay_2`, etc. and replace the unwanted RecentDelays column in `df` with `delays`.

# %%
delays = df['RecentDelays'].apply(pd.Series)

delays.columns = [f'delay_{n}' for n in range(1, len(delays.columns)+1)]

df = df.drop('RecentDelays', axis=1).join(delays)

df
# Out:
#    FlightNumber  Airline      From         To  delay_1  delay_2  delay_3
# 0         10045      KLM    London      Paris     23.0     47.0      NaN
# 1         10055      Air    Madrid      Milan      NaN      NaN      NaN
# 2         10065  British    London  Stockholm     24.0     43.0     87.0
# 3         10075      Air  Budapest      Paris     13.0      NaN      NaN
# 4         10085    Swiss  Brussels     London     67.0     32.0      NaN
