# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Getting started

# %%
my_dataset = {
  'students': ["John", "Mary", "Kiril"],
  'grades': [88, 70, 99],
  'scores': ('B+', 'C-', 'A+'),
}

my_df = pd.DataFrame(my_dataset)
my_df
# Out:
#   students  grades scores
# 0     John      88     B+
# 1     Mary      70     C-
# 2    Kiril      99     A+

# %% [markdown]
# # Series
#
# A Series is a column-vector. It is an array of individual entries, each of which has a certain value.

# %%
ages = pd.Series([18, 35, 42], name="Age")
ages
# Out:
# 0    18
# 1    35
# 2    42
# Name: Age, dtype: int64

# %%
ages[1:2]
ages.iloc[1:2]
# ages.loc[1:2]
# Out:
# 1    35
# Name: Age, dtype: int64

# %%
array = [1, 5, 'hello', 4, -10]
col_vec = pd.Series(array, name="Something")
col_vec
# Out:
# 0        1
# 1        5
# 2    hello
# 3        4
# 4      -10
# Name: Something, dtype: object

# %%
col_vec[1:4]
# Out:
# 1        5
# 2    hello
# 3        4
# Name: Something, dtype: object

# %%
array = [1, 5, 'hello', 4, -10]
col_vec = pd.Series(array, 
                    index=['a','b','c','d','e'])
col_vec
# Out:
# a        1
# b        5
# c    hello
# d        4
# e      -10
# dtype: object

# %%
col_vec['c']
col_vec['b'::2]
col_vec.iloc[1:]
col_vec.loc[['c','a']]
col_vec.loc['c':]
# Out:
# c    hello
# d        4
# e      -10
# dtype: object

# %%
grades = {"John": 88, "Mary": 70, "Kiril": 99}
my_ser = pd.Series(grades)
my_ser
# Out:
# John     88
# Mary     70
# Kiril    99
# dtype: int64

# %%
my_ser = pd.Series(grades, index = ["John", "Mary"])
my_ser
# Out:
# John    88
# Mary    70
# dtype: int64

# %%
grades = {"John": 88, "Mary": 70, "Kiril": 99, "Nadia": 90}
other_ser = pd.Series(grades)

# %%
my_ser+other_ser
# Out:
# John     176.0
# Kiril      NaN
# Mary     140.0
# Nadia      NaN
# dtype: float64

# %%
series1 = pd.Series([1, 2, 3])
series2 = pd.Series([4, 5, 6])

series1 + series2
# Out:
# 0    5
# 1    7
# 2    9
# dtype: int64

# %% [markdown]
# # Dataframes
#
# A DataFrame is a table. It contains an array of individual entries, each of which has a certain value. Each entry corresponds to a row (or record) and a column.

# %% [markdown]
# ### Toy example 1: DataFrame from a dictionary

# %%
data = {
    'Date': ['2025-01-10', '2025-01-12', '2025-01-13', '2025-01-02', '2025-01-02', '2025-01-03', '2024-05-03', '2024-05-03'],
    'Item': ['Apple', 'Banana', 'Orange', 'Apple', 'Banana', 'Orange', 'Apple', 'Orange'],
    'Units Sold': [30, 21, 15, 40, 34, 20, 45, 25],
    'Price Per Unit': [1.0, 0.5, 0.75, 1.0, 0.5, 0.75, 1.0, 0.75],
    'Salesperson': ['John', 'John', 'John', 'Alice', 'Alice', 'John', 'Alice', 'John']
}

df = pd.DataFrame(data)

# Display the DataFrame
df
# Out:
#          Date    Item  Units Sold  Price Per Unit Salesperson
# 0  2025-01-10   Apple          30            1.00        John
# 1  2025-01-12  Banana          21            0.50        John
# 2  2025-01-13  Orange          15            0.75        John
# 3  2025-01-02   Apple          40            1.00       Alice
# 4  2025-01-02  Banana          34            0.50       Alice
# 5  2025-01-03  Orange          20            0.75        John
# 6  2024-05-03   Apple          45            1.00       Alice
# 7  2024-05-03  Orange          25            0.75        John

# %% [markdown]
# ### Toy example 2: DataFrame from a matrix

# %%
toy_matrix = [[1,2,3,4],
              [4,5,6,7],
              [7,8,9,0],
              [1,1,2,5],
              [0,0,9,6],
              [0,0,10,3]
             ]
df = pd.DataFrame(toy_matrix, columns=["A", "B", "C", "D"],index=["a","b","c","d","e","f"],dtype=int)

# %%
display(df)
print(df)
df
# Out:
#    A  B   C  D
# a  1  2   3  4
# b  4  5   6  7
# c  7  8   9  0
# d  1  1   2  5
# e  0  0   9  6
# f  0  0  10  3
#    A  B   C  D
# a  1  2   3  4
# b  4  5   6  7
# c  7  8   9  0
# d  1  1   2  5
# e  0  0   9  6
# f  0  0  10  3
#    A  B   C  D
# a  1  2   3  4
# b  4  5   6  7
# c  7  8   9  0
# d  1  1   2  5
# e  0  0   9  6
# f  0  0  10  3

# %% [markdown]
# ### Summary of the basic information about the DataFrame

# %%
df.shape
# Out:
# (6, 4)

# %%
df.size
# Out:
# 24

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 6 entries, a to f
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   A       6 non-null      int32
#  1   B       6 non-null      int32
#  2   C       6 non-null      int32
#  3   D       6 non-null      int32
# dtypes: int32(4)
# memory usage: 144.0+ bytes

# %%
df.describe()
# x% percentile is the value below which x% of the data points fall
# Out:
#               A         B          C         D
# count  6.000000  6.000000   6.000000  6.000000
# mean   2.166667  2.666667   6.500000  4.166667
# std    2.786874  3.204164   3.391165  2.483277
# min    0.000000  0.000000   2.000000  0.000000
# 25%    0.250000  0.250000   3.750000  3.250000
# 50%    1.000000  1.500000   7.500000  4.500000
# 75%    3.250000  4.250000   9.000000  5.750000
# max    7.000000  8.000000  10.000000  7.000000

# %%
df.nunique()
# Return the number of unique values in each column of a DataFrame
# Out:
# A    4
# B    5
# C    5
# D    6
# dtype: int64

# %% [markdown]
# ### Head, Tail, and Sample

# %%
df.head(10)
# Out:
#    A  B   C  D
# a  1  2   3  4
# b  4  5   6  7
# c  7  8   9  0
# d  1  1   2  5
# e  0  0   9  6
# f  0  0  10  3

# %%
df.tail(3)
# Out:
#    A  B   C  D
# d  1  1   2  5
# e  0  0   9  6
# f  0  0  10  3

# %%
df.sample(5, random_state=0)
# Out:
#    A  B   C  D
# f  0  0  10  3
# c  7  8   9  0
# b  4  5   6  7
# d  1  1   2  5
# a  1  2   3  4

# %% [markdown]
# ### Getting indices (names) of columns

# %%
df.columns
# Out:
# Index(['A', 'B', 'C', 'D'], dtype='object')

# %% [markdown]
# ### Getting indices of rows

# %%
# df.rows does NOT exist
# use df.index instead
df.index
# Out:
# Index(['a', 'b', 'c', 'd', 'e', 'f'], dtype='object')

# %% [markdown]
# ## Accessing rows, columns and elements of a DataFrame

# %% [markdown]
# ### Columns
#
# - You can directly access columns using
#     - Its name
#     - Or a list/array of names
# - You CANNOT use a range!

# %%
df['B']
# Out:
# a    2
# b    5
# c    8
# d    1
# e    0
# f    0
# Name: B, dtype: int32

# %%
df[df.columns[1:3]]
# Out:
#    B   C
# a  2   3
# b  5   6
# c  8   9
# d  1   2
# e  0   9
# f  0  10

# %%
df[['B','A']]
# Out:
#    B  A
# a  2  1
# b  5  4
# c  8  7
# d  1  1
# e  0  0
# f  0  0

# %% [markdown]
# ### Rows
#
# - You can directly access rows using a range
# - An individual row CANNOT be accessed in such a way!

# %%
df['a':'c']
# but you cannot access a row / rows doing df['a'] or df[['a']] or df[['a','b']]
# Out:
#    A  B  C  D
# a  1  2  3  4
# b  4  5  6  7
# c  7  8  9  0

# %% [markdown]
# ### Rows and Columns

# %%
df['b':][["A","C"]]
# Out:
#    A   C
# b  4   6
# c  7   9
# d  1   2
# e  0   9
# f  0  10

# %%
df['b'::2][["A","C"]]
# Out:
#    A   C
# b  4   6
# d  1   2
# f  0  10

# %% [markdown]
# ### `loc` & `iloc`
# Usage: `loc[rows]` or `loc[rows, columns]`
#
# Usage: `iloc[rows]` or `iloc[rows, columns]`

# %%
df
# Out:
#    A  B   C  D
# a  1  2   3  4
# b  4  5   6  7
# c  7  8   9  0
# d  1  1   2  5
# e  0  0   9  6
# f  0  0  10  3

# %% [markdown]
# ### Rows

# %%
df.loc['b']
df.iloc[1]
# Out:
# A    4
# B    5
# C    6
# D    7
# Name: b, dtype: int32

# %%
df.loc['b':]
df.iloc[1:]
# Out:
#    A  B   C  D
# b  4  5   6  7
# c  7  8   9  0
# d  1  1   2  5
# e  0  0   9  6
# f  0  0  10  3

# %%
df.loc[['b','a','f']]
df.iloc[[1,0,5]]
# Out:
#    A  B   C  D
# b  4  5   6  7
# a  1  2   3  4
# f  0  0  10  3

# %% [markdown]
# ### Columns

# %%
df
# Out:
#    A  B   C  D
# a  1  2   3  4
# b  4  5   6  7
# c  7  8   9  0
# d  1  1   2  5
# e  0  0   9  6
# f  0  0  10  3

# %%
df.loc[:,'B']
df.iloc[:,1]
# Out:
# a    2
# b    5
# c    8
# d    1
# e    0
# f    0
# Name: B, dtype: int32

# %%
df.loc[:,['B','A']]
df.iloc[:,[1,0]]
# Out:
#    B  A
# a  2  1
# b  5  4
# c  8  7
# d  1  1
# e  0  0
# f  0  0

# %%
df.loc[:,'B'::2]
df.iloc[:,1::2]
# Out:
#    B  D
# a  2  4
# b  5  7
# c  8  0
# d  1  5
# e  0  6
# f  0  3

# %% [markdown]
# ### Row and Columns

# %%
df.loc['b':'e', ["A", "C"]]
# Out:
#    A  C
# b  4  6
# c  7  9
# d  1  2
# e  0  9

# %%
df.iloc[3:5, 1:]
# Out:
#    B  C  D
# d  1  2  5
# e  0  9  6

# %% [markdown]
# ### Individual Elements

# %%
df
# Out:
#    A  B   C  D
# a  1  2   3  4
# b  4  5   6  7
# c  7  8   9  0
# d  1  1   2  5
# e  0  0   9  6
# f  0  0  10  3

# %%
df.loc['a', 'A']
df.at['a', 'A']
# Out:
# 1

# %%
df.iloc[0,0]
df.iat[0,0]
# Out:
# 1

# %% [markdown]
# ### Difference in indexing between loc and iloc

# %%
df_reset = df.reset_index(drop=True)  # drop=True removes the old index
df_reset
# Out:
#    A  B   C  D
# 0  1  2   3  4
# 1  4  5   6  7
# 2  7  8   9  0
# 3  1  1   2  5
# 4  0  0   9  6
# 5  0  0  10  3

# %%
df_reset.loc[2:5]
# Out:
#    A  B   C  D
# 2  7  8   9  0
# 3  1  1   2  5
# 4  0  0   9  6
# 5  0  0  10  3

# %%
df_reset.iloc[2:5]
# Out:
#    A  B  C  D
# 2  7  8  9  0
# 3  1  1  2  5
# 4  0  0  9  6

# %% [markdown]
# ## Sorting

# %%
df
# Out:
#    A  B   C  D
# a  1  2   3  4
# b  4  5   6  7
# c  7  8   9  0
# d  1  1   2  5
# e  0  0   9  6
# f  0  0  10  3

# %%
df.sort_index(axis=1, ascending=False)
# Out:
#    D   C  B  A
# a  4   3  2  1
# b  7   6  5  4
# c  0   9  8  7
# d  5   2  1  1
# e  6   9  0  0
# f  3  10  0  0

# %%
df.sort_values(["A", "B", "D"], ascending=True)
# Out:
#    A  B   C  D
# f  0  0  10  3
# e  0  0   9  6
# d  1  1   2  5
# a  1  2   3  4
# b  4  5   6  7
# c  7  8   9  0

# %% [markdown]
# ## Adding, Removing, Renaming rows and columns

# %% [markdown]
# ### Adding a row

# %%
df.loc['w'] = [3, 4, 10, 999]
df
# Out:
#    A  B   C    D
# a  1  2   3    4
# b  4  5   6    7
# c  7  8   9    0
# d  1  1   2    5
# e  0  0   9    6
# f  0  0  10    3
# w  3  4  10  999

# %%
new_row = pd.DataFrame({'A': [10], 'B': [30], 'C' : [45], 'D' : [45]}, index=['v']) # Just another dataframe

df = pd.concat([df, new_row])

df
# Out:
#     A   B   C    D
# a   1   2   3    4
# b   4   5   6    7
# c   7   8   9    0
# d   1   1   2    5
# e   0   0   9    6
# f   0   0  10    3
# w   3   4  10  999
# v  10  30  45   45

# %% [markdown]
# ### Adding a column

# %% [markdown]
# #### Adding by broadcasting

# %%
df['price'] = 10
df
# Out:
#     A   B   C    D  price
# a   1   2   3    4     10
# b   4   5   6    7     10
# c   7   8   9    0     10
# d   1   1   2    5     10
# e   0   0   9    6     10
# f   0   0  10    3     10
# w   3   4  10  999     10
# v  10  30  45   45     10

# %%
df["new"] = df["A"] * df["B"]
df
# Out:
#     A   B   C    D  price  new
# a   1   2   3    4     10    2
# b   4   5   6    7     10   20
# c   7   8   9    0     10   56
# d   1   1   2    5     10    1
# e   0   0   9    6     10    0
# f   0   0  10    3     10    0
# w   3   4  10  999     10   12
# v  10  30  45   45     10  300

# %% [markdown]
# #### Adding with `np.where()`

# %%
df['new_price'] = np.where(df['A'] >= 2, 5, 3) 
df
# Out:
#     A   B   C    D  price  new  new_price
# a   1   2   3    4     10    2          3
# b   4   5   6    7     10   20          5
# c   7   8   9    0     10   56          5
# d   1   1   2    5     10    1          3
# e   0   0   9    6     10    0          3
# f   0   0  10    3     10    0          3
# w   3   4  10  999     10   12          5
# v  10  30  45   45     10  300          5

# %% [markdown]
# #### Adding with `.apply()`

# %%
df['some_category'] = df['D'].apply(lambda x: 'Short' if x < 4 else ('Average' if x < 5 else 'Tall'))
df
# Out:
#     A   B   C    D  price  new  new_price some_category
# a   1   2   3    4     10    2          3       Average
# b   4   5   6    7     10   20          5          Tall
# c   7   8   9    0     10   56          5         Short
# d   1   1   2    5     10    1          3          Tall
# e   0   0   9    6     10    0          3          Tall
# f   0   0  10    3     10    0          3         Short
# w   3   4  10  999     10   12          5          Tall
# v  10  30  45   45     10  300          5          Tall

# %%
def categorize(row):
    if row['C'] < 3 and row['D'] < 5:
        return 'Light'
    elif row['C'] < 5 or row['D'] <= 6:
        return 'Middle'
    else:
        return 'Heavy'
    
df['one more category'] = df.apply(categorize, axis=1)
df
# Out:
#     A   B   C    D  price  new  new_price some_category one more category
# a   1   2   3    4     10    2          3       Average            Middle
# b   4   5   6    7     10   20          5          Tall             Heavy
# c   7   8   9    0     10   56          5         Short            Middle
# d   1   1   2    5     10    1          3          Tall            Middle
# e   0   0   9    6     10    0          3          Tall            Middle
# f   0   0  10    3     10    0          3         Short            Middle
# w   3   4  10  999     10   12          5          Tall             Heavy
# v  10  30  45   45     10  300          5          Tall             Heavy

# %%
def random_name(_):
    first_names = ['Alice', 'Bob', 'Charlie', 'David', 'Emma', 'Frank', 'Grace', 'Helen']
    last_names = ['Smith', 'Johnson', 'Williams', 'Brown', 'Jones', 'Miller', 'Davis', 'Garcia']
    return f"{np.random.choice(first_names)} {np.random.choice(last_names)}"

df['Name'] = df.apply(random_name, axis=1)

df
# Out:
#     A   B   C    D  price  new  new_price some_category one more category  \
# a   1   2   3    4     10    2          3       Average            Middle
# b   4   5   6    7     10   20          5          Tall             Heavy
# c   7   8   9    0     10   56          5         Short            Middle
# d   1   1   2    5     10    1          3          Tall            Middle
# e   0   0   9    6     10    0          3          Tall            Middle
# f   0   0  10    3     10    0          3         Short            Middle
# w   3   4  10  999     10   12          5          Tall             Heavy
# v  10  30  45   45     10  300          5          Tall             Heavy
#
#             Name
# a   Bob Williams
# b  Alice Johnson
# c   Grace Garcia
# d      Bob Davis
# e    Alice Smith
# f    David Jones
# w   Alice Miller
# v  Charlie Jones

# %%
df['First Name'] = df['Name'].str.split(' ').str[0]
df
# Out:
#     A   B   C    D  price  new  new_price some_category one more category  \
# a   1   2   3    4     10    2          3       Average            Middle
# b   4   5   6    7     10   20          5          Tall             Heavy
# c   7   8   9    0     10   56          5         Short            Middle
# d   1   1   2    5     10    1          3          Tall            Middle
# e   0   0   9    6     10    0          3          Tall            Middle
# f   0   0  10    3     10    0          3         Short            Middle
# w   3   4  10  999     10   12          5          Tall             Heavy
# v  10  30  45   45     10  300          5          Tall             Heavy
#
#             Name First Name
# a   Bob Williams        Bob
# b  Alice Johnson      Alice
# c   Grace Garcia      Grace
# d      Bob Davis        Bob
# e    Alice Smith      Alice
# f    David Jones      David
# w   Alice Miller      Alice
# v  Charlie Jones    Charlie

# %% [markdown]
# ### Removing a row

# %%
df.drop(index=['v'], inplace=True, errors='ignore')  
df = df.drop(index=['v'], errors='ignore')
df
# Out:
#    A  B   C    D  price  new  new_price some_category one more category  \
# a  1  2   3    4     10    2          3       Average            Middle
# b  4  5   6    7     10   20          5          Tall             Heavy
# c  7  8   9    0     10   56          5         Short            Middle
# d  1  1   2    5     10    1          3          Tall            Middle
# e  0  0   9    6     10    0          3          Tall            Middle
# f  0  0  10    3     10    0          3         Short            Middle
# w  3  4  10  999     10   12          5          Tall             Heavy
#
#             Name First Name
# a   Bob Williams        Bob
# b  Alice Johnson      Alice
# c   Grace Garcia      Grace
# d      Bob Davis        Bob
# e    Alice Smith      Alice
# f    David Jones      David
# w   Alice Miller      Alice

# %% [markdown]
# ### Removing a column

# %%
df.drop(columns=['price'], inplace=True, errors='ignore')
df = df.drop(columns=['price'], errors='ignore')
df
# Out:
#    A  B   C    D  new  new_price some_category one more category  \
# a  1  2   3    4    2          3       Average            Middle
# b  4  5   6    7   20          5          Tall             Heavy
# c  7  8   9    0   56          5         Short            Middle
# d  1  1   2    5    1          3          Tall            Middle
# e  0  0   9    6    0          3          Tall            Middle
# f  0  0  10    3    0          3         Short            Middle
# w  3  4  10  999   12          5          Tall             Heavy
#
#             Name First Name
# a   Bob Williams        Bob
# b  Alice Johnson      Alice
# c   Grace Garcia      Grace
# d      Bob Davis        Bob
# e    Alice Smith      Alice
# f    David Jones      David
# w   Alice Miller      Alice

# %%
if 'price' in df.columns:
    df.drop(columns=['price'], inplace=True)

# %% [markdown]
# ### Renaming a row

# %%
df.rename(index={'w': 'x'}, inplace=True)
df
# Out:
#    A  B   C    D  new  new_price some_category one more category  \
# a  1  2   3    4    2          3       Average            Middle
# b  4  5   6    7   20          5          Tall             Heavy
# c  7  8   9    0   56          5         Short            Middle
# d  1  1   2    5    1          3          Tall            Middle
# e  0  0   9    6    0          3          Tall            Middle
# f  0  0  10    3    0          3         Short            Middle
# x  3  4  10  999   12          5          Tall             Heavy
#
#             Name First Name
# a   Bob Williams        Bob
# b  Alice Johnson      Alice
# c   Grace Garcia      Grace
# d      Bob Davis        Bob
# e    Alice Smith      Alice
# f    David Jones      David
# x   Alice Miller      Alice

# %% [markdown]
# ### Renaming a column

# %%
df.rename(columns={'new_price': 'price'}, inplace=True)
df
# Out:
#    A  B   C    D  new  price some_category one more category           Name  \
# a  1  2   3    4    2      3       Average            Middle   Bob Williams
# b  4  5   6    7   20      5          Tall             Heavy  Alice Johnson
# c  7  8   9    0   56      5         Short            Middle   Grace Garcia
# d  1  1   2    5    1      3          Tall            Middle      Bob Davis
# e  0  0   9    6    0      3          Tall            Middle    Alice Smith
# f  0  0  10    3    0      3         Short            Middle    David Jones
# x  3  4  10  999   12      5          Tall             Heavy   Alice Miller
#
#   First Name
# a        Bob
# b      Alice
# c      Grace
# d        Bob
# e      Alice
# f      David
# x      Alice

# %% [markdown]
# ## Filtering rows

# %%
df
# Out:
#    A  B   C    D  new  price some_category one more category           Name  \
# a  1  2   3    4    2      3       Average            Middle   Bob Williams
# b  4  5   6    7   20      5          Tall             Heavy  Alice Johnson
# c  7  8   9    0   56      5         Short            Middle   Grace Garcia
# d  1  1   2    5    1      3          Tall            Middle      Bob Davis
# e  0  0   9    6    0      3          Tall            Middle    Alice Smith
# f  0  0  10    3    0      3         Short            Middle    David Jones
# x  3  4  10  999   12      5          Tall             Heavy   Alice Miller
#
#   First Name
# a        Bob
# b      Alice
# c      Grace
# d        Bob
# e      Alice
# f      David
# x      Alice

# %% [markdown]
# ### Filtering with condition(s)

# %%
df.loc[df["A"] > 1]
df.loc[df["A"] > 1,:]
df[df["A"] > 1] # Without .loc
# Out:
#    A  B   C    D  new  price some_category one more category           Name  \
# b  4  5   6    7   20      5          Tall             Heavy  Alice Johnson
# c  7  8   9    0   56      5         Short            Middle   Grace Garcia
# x  3  4  10  999   12      5          Tall             Heavy   Alice Miller
#
#   First Name
# b      Alice
# c      Grace
# x      Alice

# %%
df.loc[df["A"] > 1, ["C","A", "one more category"]]
df[df["A"] > 1][["C","A","one more category"]] # Without .loc
# Out:
#     C  A one more category
# b   6  4             Heavy
# c   9  7            Middle
# x  10  3             Heavy

# %%
df[(df['A'] < 3) & (df['B'] == 0)]
# Out:
#    A  B   C  D  new  price some_category one more category         Name  \
# e  0  0   9  6    0      3          Tall            Middle  Alice Smith
# f  0  0  10  3    0      3         Short            Middle  David Jones
#
#   First Name
# e      Alice
# f      David

# %% [markdown]
# ### Filtering `nan`'s

# %%
# Let's have some NaN values in our dataframe


# Number of random NaNs to introduce
num_nans = 5  

row_indices = np.random.choice(df.index, size=num_nans)
col_indices = np.random.choice(df.columns, size=1)

df.loc[row_indices, col_indices] = np.nan
df
# Out:
#    A  B   C    D  new  price some_category one more category           Name  \
# a  1  2   3    4    2      3       Average               NaN   Bob Williams
# b  4  5   6    7   20      5          Tall             Heavy  Alice Johnson
# c  7  8   9    0   56      5         Short               NaN   Grace Garcia
# d  1  1   2    5    1      3          Tall            Middle      Bob Davis
# e  0  0   9    6    0      3          Tall               NaN    Alice Smith
# f  0  0  10    3    0      3         Short               NaN    David Jones
# x  3  4  10  999   12      5          Tall             Heavy   Alice Miller
#
#   First Name
# a        Bob
# b      Alice
# c      Grace
# d        Bob
# e      Alice
# f      David
# x      Alice

# %%
df[df['C'].notna()]
# Out:
#    A  B   C    D  new  price some_category one more category           Name  \
# a  1  2   3    4    2      3       Average               NaN   Bob Williams
# b  4  5   6    7   20      5          Tall             Heavy  Alice Johnson
# c  7  8   9    0   56      5         Short               NaN   Grace Garcia
# d  1  1   2    5    1      3          Tall            Middle      Bob Davis
# e  0  0   9    6    0      3          Tall               NaN    Alice Smith
# f  0  0  10    3    0      3         Short               NaN    David Jones
# x  3  4  10  999   12      5          Tall             Heavy   Alice Miller
#
#   First Name
# a        Bob
# b      Alice
# c      Grace
# d        Bob
# e      Alice
# f      David
# x      Alice

# %%
# Keep only rows that have any missing values
df[df.isna().any(axis=1)]
# Out:
#    A  B   C  D  new  price some_category one more category          Name  \
# a  1  2   3  4    2      3       Average               NaN  Bob Williams
# c  7  8   9  0   56      5         Short               NaN  Grace Garcia
# e  0  0   9  6    0      3          Tall               NaN   Alice Smith
# f  0  0  10  3    0      3         Short               NaN   David Jones
#
#   First Name
# a        Bob
# c      Grace
# e      Alice
# f      David

# %%
# Keep only rows that have no missing values
df[df.notna().all(axis=1)]
# Out:
#    A  B   C    D  new  price some_category one more category           Name  \
# b  4  5   6    7   20      5          Tall             Heavy  Alice Johnson
# d  1  1   2    5    1      3          Tall            Middle      Bob Davis
# x  3  4  10  999   12      5          Tall             Heavy   Alice Miller
#
#   First Name
# b      Alice
# d        Bob
# x      Alice

# %% [markdown]
# ### String filtering

# %%
df[df['some_category'].str.contains("tall", case=False)]
# Out:
#    A  B   C    D  new  price some_category one more category           Name  \
# b  4  5   6    7   20      5          Tall             Heavy  Alice Johnson
# d  1  1   2    5    1      3          Tall            Middle      Bob Davis
# e  0  0   9    6    0      3          Tall               NaN    Alice Smith
# x  3  4  10  999   12      5          Tall             Heavy   Alice Miller
#
#   First Name
# b      Alice
# d        Bob
# e      Alice
# x      Alice

# %%
# Regex syntax!
df[df['some_category'].str.contains('tall|short', case=False)]
# Out:
#    A  B   C    D  new  price some_category one more category           Name  \
# b  4  5   6    7   20      5          Tall             Heavy  Alice Johnson
# c  7  8   9    0   56      5         Short               NaN   Grace Garcia
# d  1  1   2    5    1      3          Tall            Middle      Bob Davis
# e  0  0   9    6    0      3          Tall               NaN    Alice Smith
# f  0  0  10    3    0      3         Short               NaN    David Jones
# x  3  4  10  999   12      5          Tall             Heavy   Alice Miller
#
#   First Name
# b      Alice
# c      Grace
# d        Bob
# e      Alice
# f      David
# x      Alice

# %%
df
# Out:
#    A  B   C    D  new  price some_category one more category           Name  \
# a  1  2   3    4    2      3       Average               NaN   Bob Williams
# b  4  5   6    7   20      5          Tall             Heavy  Alice Johnson
# c  7  8   9    0   56      5         Short               NaN   Grace Garcia
# d  1  1   2    5    1      3          Tall            Middle      Bob Davis
# e  0  0   9    6    0      3          Tall               NaN    Alice Smith
# f  0  0  10    3    0      3         Short               NaN    David Jones
# x  3  4  10  999   12      5          Tall             Heavy   Alice Miller
#
#   First Name
# a        Bob
# b      Alice
# c      Grace
# d        Bob
# e      Alice
# f      David
# x      Alice

# %%
df[df['A'].isin([2,3,5,7]) & (df['some_category'].str.lower().str.startswith("sh"))]
# Out:
#    A  B  C  D  new  price some_category one more category          Name  \
# c  7  8  9  0   56      5         Short               NaN  Grace Garcia
#
#   First Name
# c      Grace

# %% [markdown]
# ## Filtering columns

# %%
df
# Out:
#    A  B   C    D  new  price some_category one more category           Name  \
# a  1  2   3    4    2      3       Average               NaN   Bob Williams
# b  4  5   6    7   20      5          Tall             Heavy  Alice Johnson
# c  7  8   9    0   56      5         Short               NaN   Grace Garcia
# d  1  1   2    5    1      3          Tall            Middle      Bob Davis
# e  0  0   9    6    0      3          Tall               NaN    Alice Smith
# f  0  0  10    3    0      3         Short               NaN    David Jones
# x  3  4  10  999   12      5          Tall             Heavy   Alice Miller
#
#   First Name
# a        Bob
# b      Alice
# c      Grace
# d        Bob
# e      Alice
# f      David
# x      Alice

# %% [markdown]
# ### Selecting specific columns

# %%
df[['A', 'Name']]
# Out:
#    A           Name
# a  1   Bob Williams
# b  4  Alice Johnson
# c  7   Grace Garcia
# d  1      Bob Davis
# e  0    Alice Smith
# f  0    David Jones
# x  3   Alice Miller

# %% [markdown]
# ### Dropping columns

# %%
df.drop(columns=['A', 'B'])
# Out:
#     C    D  new  price some_category one more category           Name  \
# a   3    4    2      3       Average               NaN   Bob Williams
# b   6    7   20      5          Tall             Heavy  Alice Johnson
# c   9    0   56      5         Short               NaN   Grace Garcia
# d   2    5    1      3          Tall            Middle      Bob Davis
# e   9    6    0      3          Tall               NaN    Alice Smith
# f  10    3    0      3         Short               NaN    David Jones
# x  10  999   12      5          Tall             Heavy   Alice Miller
#
#   First Name
# a        Bob
# b      Alice
# c      Grace
# d        Bob
# e      Alice
# f      David
# x      Alice

# %% [markdown]
# ### Based on data type

# %%
df.select_dtypes(include=['number'])
# Out:
#    A  B   C    D  new  price
# a  1  2   3    4    2      3
# b  4  5   6    7   20      5
# c  7  8   9    0   56      5
# d  1  1   2    5    1      3
# e  0  0   9    6    0      3
# f  0  0  10    3    0      3
# x  3  4  10  999   12      5

# %% [markdown]
# ### By name pattern

# %%
df.filter(items=['A','C'], axis=1)
# Out:
#    A   C
# a  1   3
# b  4   6
# c  7   9
# d  1   2
# e  0   9
# f  0  10
# x  3  10

# %%
df.filter(regex='A|B|C', axis=1)
# Out:
#    A  B   C
# a  1  2   3
# b  4  5   6
# c  7  8   9
# d  1  1   2
# e  0  0   9
# f  0  0  10
# x  3  4  10

# %% [markdown]
# ### Filtering `nan`'s

# %%
# Keep columns with any missing values
df.loc[:, df.isna().any()]
# Out:
#   one more category
# a               NaN
# b             Heavy
# c               NaN
# d            Middle
# e               NaN
# f               NaN
# x             Heavy

# %%
# Keep only columns that have no missing values
df.loc[:, df.notna().all()]
# Out:
#    A  B   C    D  new  price some_category           Name First Name
# a  1  2   3    4    2      3       Average   Bob Williams        Bob
# b  4  5   6    7   20      5          Tall  Alice Johnson      Alice
# c  7  8   9    0   56      5         Short   Grace Garcia      Grace
# d  1  1   2    5    1      3          Tall      Bob Davis        Bob
# e  0  0   9    6    0      3          Tall    Alice Smith      Alice
# f  0  0  10    3    0      3         Short    David Jones      David
# x  3  4  10  999   12      5          Tall   Alice Miller      Alice

# %% [markdown]
# ## Handling Null Values

# %%
df
# Out:
#    A  B   C    D  new  price some_category one more category           Name  \
# a  1  2   3    4    2      3       Average               NaN   Bob Williams
# b  4  5   6    7   20      5          Tall             Heavy  Alice Johnson
# c  7  8   9    0   56      5         Short               NaN   Grace Garcia
# d  1  1   2    5    1      3          Tall            Middle      Bob Davis
# e  0  0   9    6    0      3          Tall               NaN    Alice Smith
# f  0  0  10    3    0      3         Short               NaN    David Jones
# x  3  4  10  999   12      5          Tall             Heavy   Alice Miller
#
#   First Name
# a        Bob
# b      Alice
# c      Grace
# d        Bob
# e      Alice
# f      David
# x      Alice

# %%
df['price'] = df['price'].fillna(df['price'].mean())
# Make sure to set this to your 'price' column if you want these changes to stick 
df
# Out:
#    A  B   C    D  new  price some_category one more category           Name  \
# a  1  2   3    4    2      3       Average               NaN   Bob Williams
# b  4  5   6    7   20      5          Tall             Heavy  Alice Johnson
# c  7  8   9    0   56      5         Short               NaN   Grace Garcia
# d  1  1   2    5    1      3          Tall            Middle      Bob Davis
# e  0  0   9    6    0      3          Tall               NaN    Alice Smith
# f  0  0  10    3    0      3         Short               NaN    David Jones
# x  3  4  10  999   12      5          Tall             Heavy   Alice Miller
#
#   First Name
# a        Bob
# b      Alice
# c      Grace
# d        Bob
# e      Alice
# f      David
# x      Alice

# %%
df['C'] = df['C'].interpolate()
df
# Out:
#    A  B   C    D  new  price some_category one more category           Name  \
# a  1  2   3    4    2      3       Average               NaN   Bob Williams
# b  4  5   6    7   20      5          Tall             Heavy  Alice Johnson
# c  7  8   9    0   56      5         Short               NaN   Grace Garcia
# d  1  1   2    5    1      3          Tall            Middle      Bob Davis
# e  0  0   9    6    0      3          Tall               NaN    Alice Smith
# f  0  0  10    3    0      3         Short               NaN    David Jones
# x  3  4  10  999   12      5          Tall             Heavy   Alice Miller
#
#   First Name
# a        Bob
# b      Alice
# c      Grace
# d        Bob
# e      Alice
# f      David
# x      Alice

# %%
df = df.dropna(subset=['C']) 
df
# Out:
# C:\Users\kkuzmin1\AppData\Roaming\Python\Python312\site-packages\IPython\core\displayhook.py:281: UserWarning: Output cache limit (currently 1000 entries) hit.
# Flushing oldest 200 entries.
#   warn('Output cache limit (currently {sz} entries) hit.\n'
#    A  B   C    D  new  price some_category one more category           Name  \
# a  1  2   3    4    2      3       Average               NaN   Bob Williams
# b  4  5   6    7   20      5          Tall             Heavy  Alice Johnson
# c  7  8   9    0   56      5         Short               NaN   Grace Garcia
# d  1  1   2    5    1      3          Tall            Middle      Bob Davis
# e  0  0   9    6    0      3          Tall               NaN    Alice Smith
# f  0  0  10    3    0      3         Short               NaN    David Jones
# x  3  4  10  999   12      5          Tall             Heavy   Alice Miller
#
#   First Name
# a        Bob
# b      Alice
# c      Grace
# d        Bob
# e      Alice
# f      David
# x      Alice

# %% [markdown]
# ## Grouping data
#
# `.groupby('some_category')` groups all rows having the same attributes (as specified in by parameter) into separate data frames.
#
# After the groupby, you need an aggregate function to summarize data in each subframe.
#
# You may do it in 2 ways:

# %%
# In each subframe, take the `price` column and summarize it
# using the `sum` function from the result
df.groupby(['some_category'])['price'].sum()
# Out:
# some_category
# Average     3
# Short       8
# Tall       16
# Name: price, dtype: int32

# %%
# In each subframe, apply the `sum` function to all numeric
# columns then extract the `price` column
df.groupby(['some_category']).sum()['price']
# Out:
# some_category
# Average     3
# Short       8
# Tall       16
# Name: price, dtype: int32

# %% [markdown]
# ## Pivot Tables

# %%
df
# Out:
#    A  B   C    D  new  price some_category one more category           Name  \
# a  1  2   3    4    2      3       Average               NaN   Bob Williams
# b  4  5   6    7   20      5          Tall             Heavy  Alice Johnson
# c  7  8   9    0   56      5         Short               NaN   Grace Garcia
# d  1  1   2    5    1      3          Tall            Middle      Bob Davis
# e  0  0   9    6    0      3          Tall               NaN    Alice Smith
# f  0  0  10    3    0      3         Short               NaN    David Jones
# x  3  4  10  999   12      5          Tall             Heavy   Alice Miller
#
#   First Name
# a        Bob
# b      Alice
# c      Grace
# d        Bob
# e      Alice
# f      David
# x      Alice

# %%
df.pivot_table(index='some_category', columns='one more category', values='price', aggfunc='mean')
# Out:
# one more category  Heavy  Middle
# some_category
# Tall                 5.0     3.0

# %%
df.pivot_table(index='some_category', columns='one more category', values='price', aggfunc=['sum', 'mean'], fill_value=0)
# Out:
#                     sum         mean
# one more category Heavy Middle Heavy Middle
# some_category
# Tall                 10      3   5.0    3.0
